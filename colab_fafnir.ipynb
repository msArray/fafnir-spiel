# %% [markdown]
# # Fafnir MCCFR AI (Colab CPU)
#
# This notebook sets up the project on Google Colab and runs validation, tests, and training on CPU.
# GPU is not used.

# %% [markdown]
# ## 1) Clone the repository

# %%
import os

repo_dir = 'fafnir-spiel'
if not os.path.exists(repo_dir):
    # !git clone https://github.com/msArray/fafnir-spiel.git
# %cd fafnir-spiel

# %% [markdown]
# ## 2) Install dependencies

# %%
# !pip -q install -r requirements.txt

# %% [markdown]
# ## 3) Validate implementation

# %%
# !python validate.py

# %% [markdown]
# ## 4) Run tests (optional)

# %%
# !python test_fafnir.py

# %% [markdown]
# ## 5) Train MCCFR model

# %%
# !python main.py train --iterations 1000 --model-path fafnir_mccfr_model.pkl --reset

# %% [markdown]
# ## 6) Continue training (optional)
# Run this after step 5 to continue from the saved model.

# %%
# !python main.py train --iterations 500 --model-path fafnir_mccfr_model.pkl --continue

# %% [markdown]
# ## Notes
# - This notebook uses CPU only.
# - To play against the server on Colab, you will need to expose the server port (e.g., via a tunneling tool).
